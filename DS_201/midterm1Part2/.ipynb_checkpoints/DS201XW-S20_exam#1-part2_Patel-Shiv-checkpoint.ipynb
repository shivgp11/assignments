# %%
import pandas as pd
import matplotlib as plt
df = pd.read_csv("Automobile_price_data_clean-f18.csv")
df
# Out:
#               make fuel-type aspiration num-of-doors   body-style  \
# 0           subaru       gas        std          two    hatchback
# 1        chevrolet       gas        std          two    hatchback
# 2            mazda       gas        std          two    hatchback
# 3           toyota       gas        std          two    hatchback
# 4       mitsubishi       gas        std          two    hatchback
# ..             ...       ...        ...          ...          ...
# 196            bmw       gas        std         four        sedan
# 197        porsche       gas        std          two  convertible
# 198  mercedes-benz       gas        std         four        sedan
# 199            bmw       gas        std          two        sedan
# 200  mercedes-benz       gas        std          two      hardtop
#
#     drive-wheels engine-location  wheel-base  length  width  ...  engine-size  \
# 0            fwd           front        93.7   156.9   63.4  ...           97
# 1            fwd           front        88.4   141.1   60.3  ...           61
# 2            fwd           front        93.1   159.1   64.2  ...           91
# 3            fwd           front        95.7   158.7   63.6  ...           92
# 4            fwd           front        93.7   157.3   64.4  ...           92
# ..           ...             ...         ...     ...    ...  ...          ...
# 196          rwd           front       110.0   197.0   70.9  ...          209
# 197          rwd            rear        89.5   168.9   65.0  ...          194
# 198          rwd           front       120.9   208.1   71.7  ...          308
# 199          rwd           front       103.5   193.8   67.9  ...          209
# 200          rwd           front       112.0   199.2   72.0  ...          304
#
#      fuel-system  bore stroke  compression-ratio horsepower peak-rpm city-mpg  \
# 0           2bbl  3.62   2.36                9.0         69     4900       31
# 1           2bbl  2.91   3.03                9.5         48     5100       47
# 2           2bbl  3.03   3.15                9.0         68     5000       30
# 3           2bbl  3.05   3.03                9.0         62     4800       35
# 4           2bbl  2.97   3.23                9.4         68     5500       37
# ..           ...   ...    ...                ...        ...      ...      ...
# 196         mpfi  3.62   3.39                8.0        182     5400       15
# 197         mpfi  3.74    2.9                9.5        207     5900       17
# 198         mpfi   3.8   3.35                8.0        184     4500       14
# 199         mpfi  3.62   3.39                8.0        182     5400       16
# 200         mpfi   3.8   3.35                8.0        184     4500       14
#
#      highway-mpg  price
# 0             36   5118
# 1             53   5151
# 2             31   5195
# 3             39   5348
# 4             41   5389
# ..           ...    ...
# 196           20  36880
# 197           25  37028
# 198           16  40960
# 199           22  41315
# 200           16  45400
#
# [201 rows x 24 columns]

# %%
df = df.drop_duplicates()
df = df.reset_index(drop=True)
df
# Out:
#               make fuel-type aspiration num-of-doors   body-style  \
# 0           subaru       gas        std          two    hatchback
# 1        chevrolet       gas        std          two    hatchback
# 2            mazda       gas        std          two    hatchback
# 3           toyota       gas        std          two    hatchback
# 4       mitsubishi       gas        std          two    hatchback
# ..             ...       ...        ...          ...          ...
# 196            bmw       gas        std         four        sedan
# 197        porsche       gas        std          two  convertible
# 198  mercedes-benz       gas        std         four        sedan
# 199            bmw       gas        std          two        sedan
# 200  mercedes-benz       gas        std          two      hardtop
#
#     drive-wheels engine-location  wheel-base  length  width  ...  engine-size  \
# 0            fwd           front        93.7   156.9   63.4  ...           97
# 1            fwd           front        88.4   141.1   60.3  ...           61
# 2            fwd           front        93.1   159.1   64.2  ...           91
# 3            fwd           front        95.7   158.7   63.6  ...           92
# 4            fwd           front        93.7   157.3   64.4  ...           92
# ..           ...             ...         ...     ...    ...  ...          ...
# 196          rwd           front       110.0   197.0   70.9  ...          209
# 197          rwd            rear        89.5   168.9   65.0  ...          194
# 198          rwd           front       120.9   208.1   71.7  ...          308
# 199          rwd           front       103.5   193.8   67.9  ...          209
# 200          rwd           front       112.0   199.2   72.0  ...          304
#
#      fuel-system  bore stroke  compression-ratio horsepower peak-rpm city-mpg  \
# 0           2bbl  3.62   2.36                9.0         69     4900       31
# 1           2bbl  2.91   3.03                9.5         48     5100       47
# 2           2bbl  3.03   3.15                9.0         68     5000       30
# 3           2bbl  3.05   3.03                9.0         62     4800       35
# 4           2bbl  2.97   3.23                9.4         68     5500       37
# ..           ...   ...    ...                ...        ...      ...      ...
# 196         mpfi  3.62   3.39                8.0        182     5400       15
# 197         mpfi  3.74    2.9                9.5        207     5900       17
# 198         mpfi   3.8   3.35                8.0        184     4500       14
# 199         mpfi  3.62   3.39                8.0        182     5400       16
# 200         mpfi   3.8   3.35                8.0        184     4500       14
#
#      highway-mpg  price
# 0             36   5118
# 1             53   5151
# 2             31   5195
# 3             39   5348
# 4             41   5389
# ..           ...    ...
# 196           20  36880
# 197           25  37028
# 198           16  40960
# 199           22  41315
# 200           16  45400
#
# [201 rows x 24 columns]

# %%
M_P = df.loc[:, ['make', 'price']]
M_P
# Out:
#               make  price
# 0           subaru   5118
# 1        chevrolet   5151
# 2            mazda   5195
# 3           toyota   5348
# 4       mitsubishi   5389
# ..             ...    ...
# 196            bmw  36880
# 197        porsche  37028
# 198  mercedes-benz  40960
# 199            bmw  41315
# 200  mercedes-benz  45400
#
# [201 rows x 2 columns]

# %%
df1 = df.groupby("make").price.mean()
df1.plot.bar()

# %%
df2 = df.loc[(df['make']=='toyota') & (df['price'] > 8000), ['make','price']]
df2.reset_index(drop=True)
# Out:
#       make  price
# 0   toyota   8058
# 1   toyota   8238
# 2   toyota   8358
# 3   toyota   8449
# 4   toyota   8778
# 5   toyota   8948
# 6   toyota   9258
# 7   toyota   9298
# 8   toyota   9538
# 9   toyota   9639
# 10  toyota   9988
# 11  toyota   9989
# 12  toyota  10698
# 13  toyota  10898
# 14  toyota  11199
# 15  toyota  11248
# 16  toyota  11549
# 17  toyota  15690
# 18  toyota  15750
# 19  toyota  15998
# 20  toyota  16558
# 21  toyota  17669

# %%
df2['make'].count()
# Out:
# 22

# %%
df3 = df.loc[(df['body-style']=='hatchback')]
df3
# Out:
#            make fuel-type aspiration num-of-doors body-style drive-wheels  \
# 0        subaru       gas        std          two  hatchback          fwd
# 1     chevrolet       gas        std          two  hatchback          fwd
# 2         mazda       gas        std          two  hatchback          fwd
# 3        toyota       gas        std          two  hatchback          fwd
# 4    mitsubishi       gas        std          two  hatchback          fwd
# ..          ...       ...        ...          ...        ...          ...
# 160      nissan       gas        std          two  hatchback          rwd
# 166        saab       gas      turbo          two  hatchback          fwd
# 169      nissan       gas        std          two  hatchback          rwd
# 175      nissan       gas      turbo          two  hatchback          rwd
# 179     porsche       gas        std          two  hatchback          rwd
#
#     engine-location  wheel-base  length  width  ...  engine-size  fuel-system  \
# 0             front        93.7   156.9   63.4  ...           97         2bbl
# 1             front        88.4   141.1   60.3  ...           61         2bbl
# 2             front        93.1   159.1   64.2  ...           91         2bbl
# 3             front        95.7   158.7   63.6  ...           92         2bbl
# 4             front        93.7   157.3   64.4  ...           92         2bbl
# ..              ...         ...     ...    ...  ...          ...          ...
# 160           front        91.3   170.7   67.9  ...          181         mpfi
# 166           front        99.1   186.6   66.5  ...          121         mpfi
# 169           front        99.2   178.5   67.9  ...          181         mpfi
# 175           front        91.3   170.7   67.9  ...          181         mpfi
# 179           front        94.5   168.9   68.3  ...          151         mpfi
#
#      bore stroke  compression-ratio horsepower peak-rpm city-mpg  highway-mpg  \
# 0    3.62   2.36                9.0         69     4900       31           36
# 1    2.91   3.03                9.5         48     5100       47           53
# 2    3.03   3.15                9.0         68     5000       30           31
# 3    3.05   3.03                9.0         62     4800       35           39
# 4    2.97   3.23                9.4         68     5500       37           41
# ..    ...    ...                ...        ...      ...      ...          ...
# 160  3.43   3.27                9.0        160     5200       19           25
# 166  3.54   3.07                9.0        160     5500       19           26
# 169  3.43   3.27                9.0        160     5200       19           25
# 175  3.43   3.27                7.8        200     5200       17           23
# 179  3.94   3.11                9.5        143     5500       19           27
#
#      price
# 0     5118
# 1     5151
# 2     5195
# 3     5348
# 4     5389
# ..     ...
# 160  17199
# 166  18150
# 169  18399
# 175  19699
# 179  22018
#
# [68 rows x 24 columns]

# %%
df3['city-mpg'].mean()
# Out:
# 26.602941176470587

# %%
df4 = df.boxplot(column='price', by='body-style', rot=45, figsize = (15,10), fontsize=12)

# %%
df5 = df.boxplot(column='price', by='make', rot=45, figsize = (15,10), fontsize = 12)
